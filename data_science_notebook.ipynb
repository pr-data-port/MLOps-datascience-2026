# %% [markdown]
# <a href="https://colab.research.google.com/github/pr-data-port/MLOps-datascience-2026/blob/main/data_science_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ingest

# %% [markdown]
# ## EDA

# %% [markdown]
# ## Modelling

# %% [markdown]
# ## Conclusion
